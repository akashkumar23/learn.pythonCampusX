# %% [markdown]
# <a href="https://colab.research.google.com/github/akashkumar23/learn.pythonCampusX/blob/main/lec_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Print** **Funtion**

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('Hello',1,4.5,True)
# Out:
# Hello 1 4.5 True

# %%
print('Hello',1,4.5,True,sep='/')
# Out:
# Hello/1/4.5/True

# %%
print('hello', end='-')
print('world', end='*')
print('akash')
# Out:
# hello-world*akash

# %% [markdown]
# **Data Types**

# %%
# Integer
print(8)
# 1*10^308
print(1e309)
# Out:
# 8
# inf

# %%
#Decimal/Float
print(8.55)
#1.7e308
print(1.7e309)
# Out:
# 8.55
# inf

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#Text/String
# There is no char datatype in python unlike in c/c++
print('Hello Wprld')
# Out:
# Hello Wprld

# %%
#complex
print(5+6j)
# Out:
# (5+6j)

# %%
#List as array in C
print([1,2,3,4,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#Dictionary
print({'name':'Nitish', 'gender':'Male', 'weight':70})
# Out:
# {'name': 'Nitish', 'gender': 'Male', 'weight': 70}

# %%
#type
type([1,2,3])
# Out:
# list

# %% [markdown]
# **Variables**

# %%
name = 'nitish'
print(name)

a = 5
b = 6
print(a+b)
# Out:
# nitish
# 11

# %%
 #Dynamic Typing
 a = 5
 #Static Typing
 int a = 5
# Out:
#   File "/tmp/ipykernel_454/1261309630.py", line 4
#     int a = 5
#         ^
# SyntaxError: invalid syntax

# %%
#Dynamic Binding
a = 5
print(a)
a = 'akash'
print(a)

#static Binding
int a = 5
# Out:
# 5
# akash

# %%
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# **Keywords & Identifiers**

# %%
 #Keywords
 #False
 #None
 #True
 #and
 #as
 #assert
 #break
 #class
 #continue
 #def
 #del
 #elif
 #else
 #except
 #finally
 #for
 #from
 #global
 #if
 #import
 #in
 #is
 #lambda
 #nonlocal
 #not
 #or
 #pass
 #raise
 #return
 #try
 #while
 #with
 #yield

# %%
#Identifiers
# cant start with a digit
# only special character that can be used is _
_ = 'akash'
print(_)
# cannt be keywords
# Out:
# akash

# %% [markdown]
# **User** **Input**

# %%
input('name bata betichod ')
# Out:
# name bata betichod asdfas
# 'asdfas'

# %%
fnum = input('enter first no ')
snum = input('enter second no ')
print(type(fnum), type(snum))
result = int(fnum) + int(snum)
print(result)

#python type conversion mai wo original wale data mai koi change nhi krta
#wo naya data banata h
# Out:
# enter first no 56
# enter second no 60
# <class 'str'> <class 'str'>
# 116

# %% [markdown]
# **Type Conversion**

# %%
 #Implicit Vs Explicit
 #str -> int
 #int('4')
 #type(int('4'))

#int to str
#str(5)

# float
float(4.4)
# Out:
# 4.4

# %% [markdown]
# **Literals**

# %%
 a = 0b1010 #binary
 print(a)
 b = 100 #decimal
 c = 0o310 #octal
 d = 0x12c #hexadecimal

 #Float Literals
 float_1 = 10.5
 float_2 = 1.5e2
 float_3 = 1.5e-3

 #Complex Literals
 x = 3.14j
 print(x.real, x.imag)
# Out:
# 10-0.0 3.14

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """"this is a multiline string with more than one line cide."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# "this is a multiline string with more than one line cide.
# 😀😆🤣
# raw \n string

# %%
a = True + 4
b = False + 10

print("a: ", a)
print("b: ", b)
# Out:
# a:  5
# b:  10

# %%
a = None
print(a)
