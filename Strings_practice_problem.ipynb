# %% [markdown]
# <a href="https://colab.research.google.com/github/akashkumar23/learn.pythonCampusX/blob/main/Strings_practice_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #find length of a given string without using len() fnction

 s = input()
 count = 0
 for i in s:
  count = count + 1

 print(count)
# Out:
# hgdftyf jhyyuyuf
# 16

# %%
# Extract username from the a given email

email = input()




pos = email.find('@')
print(email[:pos])
# Out:
# asdfasdgasdfg676465@gmail.com
# asdfasdgasdfg676465

# %%
#Count the frequency of a particular char in a given string
s = input()
val = input()
print('freq', s.count(val))
# Out:
# my name is nitish
# i
# freq 3

# %%
s = input()
term = input()
count = 0
for i in s:
  if i == term:
    count += 1
print('freq', count)
# Out:
# my name is nitish
# i
# freq 3

# %%
# write a program to remove a particular character from a string
s = input()
term = input()

result = ''
for i in s:
  if i!=term:
    result += i
print(result)
# Out:
# my name is akash
# a
# my nme is ksh

# %%
#write a program to check if a string is palindrome or not
s = input()

flag = True
for i in range(0,len(s)//2):
  if s[i] != s[len(s)-i-1]:
    flag = False
    break

if flag == True:
  print('Palindrome')
else:
  print('Not a Palindrome')
# Out:
# malayalam
# Palindrome

# %%
 #Write a program to count the number of words in a string without split()

s = input()
l = []
tmp = ''

for i in s:
  if i!=' ':
    tmp = tmp + i
  else:
    l.append(tmp)
    tmp = ''

l.append(tmp)
print(l)
print(len(l))
# Out:
# hi how are you akash
# ['hi', 'how', 'are', 'you', 'akash']
# 5

# %%
#Write a python program to convert a string to title case without using the title()


s = input()
L = []
for i in s.split():
  L.append(i[0].upper() + i[1:].lower())
print(" ".join(L))
# Out:
# hi HoW arE yoU AkASh
# Hi How Are You Akash

# %%
#Write a code to convert an interger to string

str(489)
# Out:
# '489'

# %%
n = int(input('enter the number'))

digits = '0123456789'
result = ''
while n!=0:
  result = digits[n%10] + result
  n = n // 10

print(result)
print(type(result))
# Out:
# enter the number981987
# 981987
# <class 'str'>
